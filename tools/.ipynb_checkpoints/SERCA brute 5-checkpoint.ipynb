# %%
import subprocess
#from multiprocessing import Pool
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# %run averaging.ipynb
# %run optimize_slope.ipynb

# %%
vol_er = (3.9*0.1*0.1)
vol_cyt = (4.0*0.5*0.5-vol_er)
vol_tot = vol_cyt + vol_er
N_avo=6.0221409e23

# %%
def write_mdl(file_name,outfolder,iterations,ic,sf,sm,serca_frac,write=True):
    ftext = """sprintf(my_seed,"%05g",SEED)

    iterations = e3

    INCLUDE_FILE = "../outputLoc.mdl"
    INCLUDE_FILE = "../initialization.mdl"
    INCLUDE_FILE = "parameters.mdl"
    /* Modifications in Parameters */
        VDCC_number_presynaptic = 40

        n_Glu_neuron =  1 //2000
        GluT_density_astrocyte = 0.1 //1000

        ca_conc_presynaptic_er = e-6     //initial ER conc specified here!!!!!
        //ryr_number_presynaptic = 0 //no RYR

    f =                                 //SERCA parameter adjustments here!!!!!!!!!!

    sm = //multiply all serca parameters

    /*Initial SERCA fractions*/
    serca_x1_feq = 
    serca_x1a_feq = 
    serca_x2_feq = 
    serca_y1_feq = 
    serca_y1a_feq = 
    serca_y2_feq = 

    INCLUDE_FILE = "rxn_rate_constants.mdl"
    /* Modifications in Reaction Rate Constants */
    //k_PMCA_0_1 = 0
    //k_PMCA_0_leak = 0


    /* Output Folder */
            //isi = "40"
        sprintf(VDCC, "%g", VDCC_number_presynaptic)
        sprintf(f_mult, "%g", f) 
        sprintf(s_mult, "%g", sm) 
        sprintf(init_er_conc, "%g", ca_conc_presynaptic_er*1e6)   	
        fname = 

        output_folder = outputLoc & "ppf/" & fname & "/sm" & s_mult & "/" & f_mult & "/" & init_er_conc & "/s_" & my_seed

    /* Rates for P/Q-type Voltage Dependent Calcium Channels */
    /* From Bischoffberger et al., 2005, , Biophys. J.*/

        k_VDCC_PQ_C01 = 0
        k_VDCC_PQ_C12 = 0
        k_VDCC_PQ_C23 = 0
        k_VDCC_PQ_C34 = 0
        k_VDCC_PQ_C43 = 0
        k_VDCC_PQ_C32 = 0
        k_VDCC_PQ_C21= 0
        k_VDCC_PQ_C10 = 0
        k_VDCC_PQ_Ca = 0

    INCLUDE_FILE = "triggered_release.inc.mdl"

    INCLUDE_FILE = "rxn_outputRS.mdl"
    //INCLUDE_FILE = "viz_output.mdl"
    """
    ftext=ftext.replace('iterations = ', 'iterations = '+str(iterations))
    ftext=ftext.replace('sm = ', 'sm = '+str(sm))
    ftext=ftext.replace('ca_conc_presynaptic_er = ', 'ca_conc_presynaptic_er = '+str(ic))
    ftext=ftext.replace('f = ','f = '+str(sf))
    ftext=ftext.replace('fname = ','fname = '+'"'+str(outfolder)+'"')
    for i,p in enumerate(['x1','x1a','x2','y2','y1a','y1']):
        old="serca_"+p+"_feq = "
        new="serca_"+p+"_feq = "+str(serca_frac[i])
        ftext=ftext.replace(old,new)
    if write:
        with open(file_name,'w') as wfile:
            wfile.write(ftext)

# %%
#checking new sm at 250uM equilibrium, do they maintain the equilibrium
ic=250
folder="/home/kabir/Project/tripartiteSynapse/brute750_7/"
outfolder="brute8"
serca_frac=[0.75554529, 0.18054556, 0.010757505, 0.015718635, 0.026363904, 0.011069105]
serca_mult=[1]#,3,6,9,12,15]
serca_f=[1]
iterations=5000
fnames=[]

for sm in serca_mult:
    for sf in serca_f:
        file_name=folder+"RSnostim_sm"+str(sm)+"_"+str(sf)+"_"+str(ic)+".mdl"
        fnames.append(file_name)
        write_mdl(file_name,outfolder,iterations,ic,sf,sm,serca_frac,write=True)

# %%
#checking new sm at 500uM equilibrium, do they maintain the equilibrium
ic=500
folder="/home/kabir/Project/tripartiteSynapse/brute750_7/"
outfolder="brute8"
serca_frac=[6.42444113e-01, 3.07147043e-01, 3.67110945e-02, 5.34887244e-03, 6.42154346e-03, 1.92733239e-03]
serca_mult=[3,6,9,12,15]
serca_f=[2]
iterations=5000
fnames=[]

for sm in serca_mult:
    for sf in serca_f:
        file_name=folder+"RSnostim_sm"+str(sm)+"_"+str(sf)+"_"+str(ic)+".mdl"
        fnames.append(file_name)
        write_mdl(file_name,outfolder,iterations,ic,sf,sm,serca_frac,write=True)

# %%
#checking new sm at 750uM equilibrium, do they maintain the equilibrium
ic=750
folder="/home/kabir/Project/tripartiteSynapse/brute750_7/"
outfolder="brute8"
serca_frac=[0.53122686, 0.38096253, 0.0683006 , 0.00995152, 0.00796481, 0.00159368]
serca_mult=[3,6,9,12,15]
serca_f=[3]
iterations=5000
fnames=[]

for sm in serca_mult:
    for sf in serca_f:
        file_name=folder+"RSnostim_sm"+str(sm)+"_"+str(sf)+"_"+str(ic)+".mdl"
        fnames.append(file_name)
        write_mdl(file_name,outfolder,iterations,ic,sf,sm,serca_frac,write=True)

# %%
#checking new sf at 500uM equilibrium, do they maintain the equilibrium
ic=500
folder="/home/kabir/Project/tripartiteSynapse/brute750_7/"
outfolder="brute8"
serca_frac=[6.42444113e-01, 3.07147043e-01, 3.67110945e-02, 5.34887244e-03, 6.42154346e-03, 1.92733239e-03]
serca_mult=[1]#,3,6,9,12,15]
serca_f=[1,1.2,1.4,1.6,1.8,1.9,2.0,2.1,2.2,2.4,2.6,2.8,3.0]
iterations=5000
fnames=[]

for sm in serca_mult:
    for sf in serca_f:
        file_name=folder+"RSnostim_sm"+str(sm)+"_"+str(sf)+"_"+str(ic)+".mdl"
        fnames.append(file_name)
        write_mdl(file_name,outfolder,iterations,ic,sf,sm,serca_frac,write=True)

# %%
#checking new sf at 750uM equilibrium, do they maintain the equilibrium
ic=750
folder="/home/kabir/Project/tripartiteSynapse/brute750_7/"
outfolder="brute8"
serca_frac=[0.53122686, 0.38096253, 0.0683006 , 0.00995152, 0.00796481, 0.00159368]
serca_mult=[1]#,3,6,9,12,15]
serca_f=[2,2.2,2.4,2.6,2.8,2.9,3,3.1,3.2,3.4,3.6,3.8,4]
iterations=5000
fnames=[]

for sm in serca_mult:
    for sf in serca_f:
        file_name=folder+"RSnostim_sm"+str(sm)+"_"+str(sf)+"_"+str(ic)+".mdl"
        fnames.append(file_name)
        write_mdl(file_name,outfolder,iterations,ic,sf,sm,serca_frac,write=True)

# %%
#write run.sh
with open(folder+'run.sh','w') as f:
    for name in fnames:
            f.write("qsub -N "+name.replace('.mdl','').replace(folder,'')+" -v I='"+name.replace('/kabir/Project/','/subhadra/kabir/')+"' pbs.py\n")

# %%
#sync script files to cluster
p=subprocess.call(["rsync","-arhP",folder[:-1],"subhadra@192.168.1.244:/home/subhadra/kabir/tripartiteSynapse/"])

# %%
#sync data back to this system
p=subprocess.call(["rsync","-arhP","subhadra@192.168.1.244:/storage/subhadra/kabir/output/ppf/brute8","/data/kabir/output/ppf/"])

# %%
#average 500 for f
ic=500

#serca_mult=[3,6,9,12,15]
#serca_f=[2]

serca_mult=[1]
serca_f=[1,1.2,1.4,1.6,1.8,1.9,2,2.1,2.2,2.4,2.6,2.8,3]

for sm in serca_mult:
    for sf in serca_f:
        averager("/data/kabir/output/ppf/brute8/sm"+str(sm)+"/"+str(sf)+"/"+str(ic)+"/")
        
#load data 500
data={}
ic=500
for sm in serca_mult:
    data[sm]={}
    for sf in serca_f:
        data_file='/data/kabir/output/ppf/brute8/sm'+str(sm)+"/"+str(sf)+'/'+str(ic)+'/Average/ca.dat'
        #print data_file
        data[sm][sf]=np.loadtxt(data_file)
        data[sm][sf].T[1]*=1e15/N_avo/vol_er*1e6 #micromolar

# %%
#average 750 for f
ic=750

#serca_mult=[3,6,9,12,15]
#serca_f=[3]

serca_mult=[1]#[3,6,9,12,15]#[1]
serca_f=[2,2.2,2.4,2.6,2.8,2.9,3,3.1,3.2,3.4,3.6,3.8,4]

for sm in serca_mult:
    for sf in serca_f:
        averager("/data/kabir/output/ppf/brute8/sm"+str(sm)+"/"+str(sf)+"/"+str(ic)+"/")
        
#load data 750
data={}
for sm in serca_mult:
    data[sm]={}
    for sf in serca_f:
        data_file='/data/kabir/output/ppf/brute8/sm'+str(sm)+"/"+str(sf)+'/'+str(ic)+'/Average/ca.dat'
        #print data_file
        data[sm][sf]=np.loadtxt(data_file)
        data[sm][sf].T[1]*=1e15/N_avo/vol_er*1e6 #micromolar """

# %%
#plot 500 or 750, change the savefile name tho

# %run optimize_slope.ipynb
color=["#0074D9", "#FF851B", "#EE2255", "#001f3f", "#85144b", "#39CCCC", "#FFDC00",
       "#2ECC40", "#7FDBFF", "#B10DC9", "#3D9970", "#AAAAAA", "#000000"]
#sm=1
plt.figure(figsize=(10,6))
for i,sf in enumerate(serca_f):
    ydata=data[sm][sf].T[1]
    xdata=data[sm][sf].T[0]
    #ydata = gaussian_filter1d(ydata, sigma=0)
    plt.plot(xdata,ydata,color=color[i%12],label='sf = '+str(sf), alpha=0.7)
    #print("(Optimum sf, error)=",optimize_slope(data[sm],250))
plt.legend()
plt.title("New sm and equilibrium at "+str(ic)+"uM")
plt.xlabel('time (sec)')
plt.ylabel('ER Ca2+ conc (uM)')
#plt.ylim((490,260))
#plt.savefig('/home/kabir/Project/plots/brute6/new_sf_'+str(ic)+'.eps')#"""
#plt.savefig('/home/kabir/Project/midsemreport_spring2019/new_sm.eps')
#print(optimize_slope(data[sm],750))

# %%
#plot 500 or 750, change the savefile name tho
#this is for different sm
# %run optimize_slope.ipynb
color=["#0074D9", "#FF851B", "#EE2255", "#001f3f", "#85144b", "#39CCCC", "#FFDC00",
       "#2ECC40", "#7FDBFF", "#B10DC9", "#3D9970", "#AAAAAA", "#000000"]

serca_mult=[3,6,9,12,15]
plt.figure(figsize=(10,6))
for i,sm in enumerate(serca_mult):
    ydata=data[sm][sf].T[1]
    xdata=data[sm][sf].T[0]
    #ydata = gaussian_filter1d(ydata, sigma=0)
    plt.plot(xdata,ydata,color=color[i%12],label='sm = '+str(sm), alpha=0.7)
    #print("(Optimum sf, error)=",optimize_slope(data[sm],250))
plt.legend()
plt.title("New sm and equilibrium at 500uM")
plt.xlabel('time (sec)')
plt.ylabel('ER Ca2+ conc (uM)')
#plt.ylim((490,260))
#plt.savefig('/home/kabir/Project/plots/brute6/new_sf_500.eps')#"""
#plt.savefig('/home/kabir/Project/midsemreport_spring2019/new_sm.eps')
#print(optimize_slope(data[sm],750))

# %%
#plot 250
# %run optimize_slope.ipynb
color=["#0074D9", "#FF851B", "#EE2255", "#001f3f", "#85144b", "#39CCCC", "#FFDC00",
       "#2ECC40", "#7FDBFF", "#B10DC9", "#3D9970", "#AAAAAA", "#000000"]
plt.figure(figsize=(10,6))
for i,sm in enumerate(serca_mult):
    sf=serca_f[0]
    ydata=data[sm][sf].T[1]
    xdata=data[sm][sf].T[0]
    #ydata = gaussian_filter1d(ydata, sigma=0)
    plt.plot(xdata,ydata,color=color[i%12],label='sm = '+str(sm), alpha=0.7)
    #print("(Optimum sf, error)=",optimize_slope(data[sm],250))
plt.legend()
plt.title("New sm and equilibrium at 250uM")
plt.xlabel('time (sec)')
plt.ylabel('ER Ca2+ conc (uM)')
plt.ylim((240,260))
plt.savefig('/home/kabir/Project/plots/brute6/new_sm.eps')#"""
plt.savefig('/home/kabir/Project/midsemreport_spring2019/new_sm.eps')
#print(optimize_slope(data[sm],750))

# %% [raw]
# #sync data back to this system
# p=subprocess.call(["rsync","-arhP","subhadra@192.168.1.244:/storage/subhadra/kabir/output/ppf/brute7","/data/kabir/output/ppf/"])

# %%
#average
# %run averaging.ipynb
ic=500

serca_mult=[3,6,9,12]
serca_f=[1.8,1.9,2,2.1,2.2]

for sm in serca_mult:
    for sf in serca_f:
        averager("/data/kabir/output/ppf/brute7/sm"+str(sm)+"/"+str(sf)+"/"+str(ic)+"/")

# %%
data={}
ic=500
for sm in serca_mult:
    data[sm]={}
    for sf in serca_f:
        data_file='/data/kabir/output/ppf/brute7/sm'+str(sm)+"/"+str(sf)+'/'+str(ic)+'/Average/ca.dat'
        #print data_file
        data[sm][sf]=np.loadtxt(data_file)
        data[sm][sf].T[1]*=1e15/N_avo/vol_er*1e6 #micromolar

# %%
#plot
color=["#0074D9", "#FF851B", "#EE2255", "#001f3f", "#85144b", "#39CCCC", "#FFDC00",
       "#2ECC40", "#7FDBFF", "#B10DC9", "#3D9970", "#AAAAAA", "#000000"]
sm=3


for sm in serca_mult:
    plt.figure(figsize=(20,12))
    for i,sf in enumerate(serca_f):
        ydata=data[sm][sf].T[1]
        xdata=data[sm][sf].T[0]
        #ydata = gaussian_filter1d(ydata, sigma=0)
        plt.plot(xdata,ydata,color=color[i%12],label='sf='+str(sf), alpha=0.7)
    plt.legend()
    plt.title('SERCA sm='+str(sm))
    plt.xlabel('time (sec)')
    plt.ylabel('ER Ca2+ conc (uM)')
    plt.savefig('/home/kabir/Project/plots/brute6/sm'+str(sm)+'eq'+'500'+'.eps')
    print("(Optimum sf, error)=",optimize_slope(data[sm],500))
# Out:
# (Optimum sf, error)= (1.7655794374919875, 3.6497850579697717)
# (Optimum sf, error)= (1.7301762232252, 3.726204741256155)
# (Optimum sf, error)= (1.6210557875961857, 3.5733720205084714)
# (Optimum sf, error)= (1.597539522528914, 4.31768735552835)

# %%
#average the data over seeds
initial_conc=[350,450,550,650,700]

#averager("/data/kabir/output/ppf/brute6/4.3/350")
sf=4.3
for ic in initial_conc:
    #print(sm,ic)
    averager("/data/kabir/output/ppf/brute6/"+str(sf)+"/"+str(ic)+"/")

# %%
# 750 load data
color=["#0074D9", "#FF851B", "#EE2255", "#001f3f", "#85144b", "#39CCCC", "#FFDC00",
       "#2ECC40", "#7FDBFF", "#B10DC9", "#3D9970", "#AAAAAA", "#000000"]

data={}

initial_conc=[350,450,550,650,700]
sf=4.3


for ic in initial_conc:
    data_file='/data/kabir/output/ppf/brute6/'+str(sf)+'/'+str(ic)+'/Average/ca.dat'
    #print data_file
    data[ic]=np.loadtxt(data_file)

    data[ic].T[1]*=1e15/N_avo/vol_er*1e6 #micromolar

# %%
#plot 750 plots
plt.figure(figsize=(30,18))

for i,ic in enumerate(initial_conc):
    ydata=data[ic].T[1]
    xdata=data[ic].T[0]
    #ydata = gaussian_filter1d(ydata, sigma=0)
    plt.plot(xdata,ydata,color=color[i%12],label=str(ic), alpha=0.7)
    
    b="""popt,pcov=curve_fit(line_fit,xdata,ydata)
    fit.append(popt)
    var.append(pcov[0][0])
    xdata = np.linspace(0, 1.4, 50)
    plt.plot(xdata, line_fit(xdata, *fit[i]), color=color[i])"""
    
plt.xlabel('time (sec)')
plt.ylabel('ER Ca2+ conc (uM)')
plt.legend()    
plt.savefig('/home/kabir/Project/plots/brute5/serca_f'+str(ic)+'.eps')

# %%
l=data[350].T[0]
print(all([l[i] <= l[i+1] for i in range(len(l)-1)]))
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  ...]

# %%
list(data.keys())
# Out:
# [3, 6, 9, 12]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-261-75ef082cc1c8> in <module>()
# ----> 1 import bohrium
#
# ModuleNotFoundError: No module named 'bohrium'
