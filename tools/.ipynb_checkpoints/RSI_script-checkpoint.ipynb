# %%
import subprocess
from multiprocessing import Pool,cpu_count
import os
from itertools import product,repeat
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.interpolate import spline
from scipy.ndimage.filters import gaussian_filter1d
from scipy import stats
import fileinput as fi

# %run averaging.ipynb
# %run optimize_slope.ipynb

ncores=cpu_count()

# %%
area_er = 2*(3.9+0.1+0.1*0.1+3.9*0.1)
vol_er = (3.9*0.1*0.1)
vol_cyt = (4.0*0.5*0.5-vol_er)
vol_tot = vol_cyt + vol_er
N_avo=6.0221409e23

# %% [markdown]
# # Initial RSnostim equilibrium check

# %%
sims=["R150control","R150ER2x","R150ER3x","R300ER2x","R300ER3x"]
data_loc="/data/kabir/output/ppf/"
sim_type="RSnostim"

data_type=["ca.dat","pmca&leak_ca_flux.dat","serca_ca_flux.dat"]

plt.figure(figsize=(10,6))
for s in sims:
    data_folder=data_loc+s+'/'+sim_type
    data_file=data_folder+"/s_00001/dat/"+data_type[0]
    ca_dat=np.loadtxt(data_file)
    #print(ca_dat)
    ydata=ca_dat.T[3]*1e15/N_avo/vol_er*1e6
    #ydata=ca_dat.T[2]-ca_dat.T[1]
    xdata=ca_dat.T[0]
    plt.plot(xdata,ydata,label=s)
plt.legend()


plt.ylim((480,510))
# Out:
# (480, 510)

# %% [markdown]
# # Search and Replace in files

# %%
dataloc="/home/kabir/Project/tripartiteSynapse/mcell/R300ER2x/"
files=os.listdir(dataloc)
RSI_files=[]
for f in files:
    if "RSI" in f:
        RSI_files.append(f)
#RSI_files

# %%
for fn in RSI_files:
    with fi.FileInput(dataloc+fn,inplace=True, backup='.bak') as f:
        for line in f:
            print(line.replace('"ppf/"','"ppf/R300ER2x/"'), end='')

# %% [markdown]
# # kleak conversion to mcell

# %%
#from S Bandara et al 2013
J=0.07*250 #uM/s
J/=1e15/N_avo/vol_er*1e6
print("Ca Flux in ions/sec = ",J)

p=[2.1675959461586873, 6.214988757731395]
kleak=(J-p[1])/p[0]
print("Predicted kleak = ",kleak)
# Out:
# Ca Flux in ions/sec =  411.01111642500007
# Predicted kleak =  186.74888573427603

# %% [markdown]
# # creating run.sh file

# %%
def seed_num(fname):
    vdcc_num=int(fname.split('V')[1].replace('.mdl',''))
    if vdcc_num>=110 and vdcc_num<=160:
        return 1000
    elif vdcc_num>=90 and vdcc_num<=100:
        return 2000
    elif vdcc_num>=70 and vdcc_num<=80:
        return 3000
    elif vdcc_num>=40 and vdcc_num<=60:
        return 5000
    else:
        return 10

# %%
a="""for name in fnames:
    input_loc=script_folder+'/'+name.replace('V90','V80')
    output_loc=script_folder+'/'+name
    with open(input_loc,'r') as infile:
        lines=infile.readlines()
    
    lines=[line.replace("VDCC_number_presynaptic = 80","VDCC_number_presynaptic = 90") for line in lines]
        
    with open(output_loc,'w') as outfile:
        outfile.writelines(lines)
#"""

# %%
#ISI range

sims=["R150control","R150ER2x","R300ER2x","R150ER3x","R300ER3x"]
sim_type=sims[0]
script_folder="/home/kabir/Project/tripartiteSynapse/mcell"+'/'+sim_type
print(script_folder)
isi=list(range(20,101,20))
VDCC=[90]
print('isi = '+str(isi),'\nvdcc = '+str(list(VDCC)))
fnames=[]
for (i,v) in product(isi,VDCC):
    fnames.append("RSI"+str(i)+"V"+str(v)+".mdl")
#fnames=["RSI20V90.mdl","RSI30V90.mdl","RSI40V90.mdl"]
print(fnames)
#seed_num=1000
# Out:
# /home/kabir/Project/tripartiteSynapse/mcell/R150control
# isi = [20, 40, 60, 80, 100]
# vdcc = [90]
# ['RSI20V90.mdl', 'RSI40V90.mdl', 'RSI60V90.mdl', 'RSI80V90.mdl', 'RSI100V90.mdl']

# %%
#VDCC range

sims=["R150control","R150ER2x","R300ER2x","R150ER3x","R300ER3x"]
sim_type=sims[2]
script_folder="/home/kabir/Project/tripartiteSynapse/mcell"+'/'+sim_type
print(script_folder)
isi=[20]
VDCC=list(range(60,101,20))
print('isi = '+str(isi),'\nvdcc = '+str(list(VDCC)))
fnames=[]
for (i,v) in product(isi,VDCC):
    fnames.append("RSI"+str(i)+"V"+str(v)+".mdl")
print(fnames)
# Out:
# /home/kabir/Project/tripartiteSynapse/mcell/R300ER2x
# isi = [20]
# vdcc = [60, 80, 100]
# ['RSI20V60.mdl', 'RSI20V80.mdl', 'RSI20V100.mdl']

# %%
#write run.sh
with open(script_folder+'/run.sh','w') as f:
    for name in fnames:
            loc=script_folder+'/'+name
            f.write("sed --i 's/^#PBS -J.*/#PBS -J 1-"+str(seed_num(name))+"/' pbs.py\n")
            f.write("qsub -N "+name.replace(".mdl",sim_type).replace("RSI",'I')+" -v I='"+loc.replace('/kabir/Project/','/subhadra/kabir/')+"' pbs.py\n")
            f.write("\n")

#sync script files to cluster
p=subprocess.call(["rsync","-arhP",script_folder,"subhadra@192.168.1.244:/home/subhadra/kabir/tripartiteSynapse/mcell/"])
# Out:
# /home/kabir/Project/tripartiteSynapse/mcell/R300ER2x
# isi = [20]
# vdcc = [60]
# ['RSI20V60.mdl']

# %%
outfolder='AD/RSI40V90'

# %%
outfolder='AD'#RSI40V90'

# %%
#sync data back to this system
p=subprocess.call(["rsync","-arhP","subhadra@192.168.1.244:/storage/subhadra/kabir/output/ppf/"+outfolder,"/data/kabir/output/ppf/"])

# %%
outfolder='R150control'#RSI40V90'

# %%
#sync data back to this system
p=subprocess.call(["rsync","-arhP","subhadra@192.168.1.244:/storage/subhadra/kabir/output/ppf/"+outfolder,"/data/kabir/output/ppf/"])

# %%
# %run analysis.ipynb
p=Pool(ncores)
#print(fnames)
p.starmap(all_analysis,product(fnames,sims[0:2]))
#all_analysis(fnames[-1])
#all_analysis("RSI20V90","R150ER2x")
# Out:
# R150ER2x RSI20V90.mdl
# R150ER2x RSI40V90.mdl
# R150control RSI60V90.mdl
# R300ER2x RSI40V90.mdl
# R150control RSI20V90.mdl
# R150control RSI40V90.mdl
# R150ER2x RSI60V90.mdl
#
# Calculating Average of
# Calculating Average ofR300ER2x RSI20V90.mdl
#
# Calculating Average of
# Calculating Average of
# Calculating Average of
# Calculating Average of /dat/ca.dat
#
# Calculating Average of
# Calculating Average of /dat/ca.dat
#  /dat/ca.dat
#  /dat/ca.dat
#  /dat/ca.dat
#  /dat/ca.dat
#  /dat/ca.dat
# RSI40V90
# RSI40V90
# RSI40V90
# RSI60V90
#  /dat/ca.dat
# RSI60V90
# seeds:  2000
# RSI20V90
# RSI20V90
# seeds:  2000
# seeds:  2000
# seeds:  2000
# seeds:  2000
# seeds:  2000
# seeds:  2000
# RSI20V90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150ER2x/RSI40V90/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  40
# vdcc:  90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI20V90/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  20
# vdcc:  90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI40V90/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI20V90/ca.dat
# isi:  40
# vdcc:  90
# seeds:  2000
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150ER2x/RSI60V90/ca.dat
# isi:  20
# vdcc:  90
# seeds:  2000
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI40V90/ca.dat
# isi:  60
# vdcc:  90
# seeds:  2000
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  40
# vdcc:  90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150ER2x/RSI20V90/ca.dat
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI60V90/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  20
# vdcc:  90
# seeds:  2000
# isi:  60
# vdcc:  90
# seeds:  2000
# resampling: 100
# resampling: 200
# resampling: 300
# resampling: 400
# resampling: 500
# resampling: 600
# resampling: 100
# resampling: 200
# resampling: 700
# resampling: 100
# resampling: 300
# resampling: 800
# resampling: 200
# resampling: 400
# resampling: 900
# resampling: 300
# resampling: 500
# resampling: 1000
# Vesicle release stats:
#  [0.2011029999999998, 0.009258908736994862, 0.5785769999999997, 0.011266191503786892, 2.883252602462582, 0.14683101788480596, 0.40561047313652093, 0.012571456075170106, 0.5943895268634788, 0.012571456075170111, 0.48429304092754644, 0.026384183708816875, 0.5157069590724538, 0.02638418370881686, 40.0, 90.0]
# resampling: 400
# resampling: 100
# resampling: 600
# resampling: 500
# isi:  40
# vdcc:  90
# Ca stats:
#  [2.20000000e-03 1.16223710e+01 2.01596827e-02 4.22000000e-02
#  1.59446500e+01 3.05912914e-02]
# Ca stats:
#  [2.20000000e-03 1.16223710e+01 2.01596827e-02 4.22000000e-02
#  1.59446500e+01 3.05912914e-02 4.00000000e+01 9.00000000e+01]
# R300ER2x RSI60V90.mdl
#
# Calculating Average of /dat/ca.dat
# RSI60V90
# seeds:  2000
# resampling: 700
# resampling: 200
# resampling: 600
# resampling: 800
# resampling: 300
# resampling: 700
# resampling: 900
# resampling: 400
# resampling: 800
# resampling: 1000
# Vesicle release stats:
#  [0.2010995, 0.009172150770130194, 0.48320250000000065, 0.011320677707186966, 2.4077797882856156, 0.12307607375262045, 0.51141231149986, 0.012587992021768584, 0.48858768850013995, 0.012587992021768577, 0.5381886876266777, 0.024927074641298185, 0.4618113123733223, 0.024927074641298192, 60.0, 90.0]
# resampling: 500
# isi:  60
# vdcc:  90
# Ca stats:
#  [2.20000000e-03 1.16223710e+01 2.01596827e-02 6.22000000e-02
#  1.52956000e+01 2.83739540e-02]
# Ca stats:
#  [2.20000000e-03 1.16223710e+01 2.01596827e-02 6.22000000e-02
#  1.52956000e+01 2.83739540e-02 6.00000000e+01 9.00000000e+01]
# R150control RSI80V90.mdl
#
# Calculating Average of /dat/ca.dat
# RSI80V90
# seeds:  2000
# resampling: 900
# resampling: 600
# resampling: 1000
# Vesicle release stats:
#  [0.24974350000000003, 0.009324133083027082, 0.7816539999999998, 0.009414100275650353, 3.1343708673417328, 0.1273274109292823, 0.1976516898281265, 0.0104988601496537, 0.8023483101718732, 0.0104988601496537, 0.28053237587734187, 0.020266714477602137, 0.7194676241226573, 0.020266714477602147, 20.0, 90.0]
# isi:  20
# vdcc:  90
# Ca stats:
#  [2.25000000e-03 1.15969150e+01 2.21679218e-02 2.22000000e-02
#  1.79384040e+01 3.97757643e-02]
# Ca stats:
#  [2.25000000e-03 1.15969150e+01 2.21679218e-02 2.22000000e-02
#  1.79384040e+01 3.97757643e-02 2.00000000e+01 9.00000000e+01]
# R150ER2x RSI80V90.mdl
#
# Calculating Average of /dat/ca.dat
# RSI80V90
# seeds:  2000
# resampling: 700
# resampling: 800
# resampling: 900
# resampling: 1000
# Vesicle release stats:
#  [0.24382149999999994, 0.009810906571260377, 0.6780790000000014, 0.010378933423044964, 2.785684687700234, 0.1230901278453479, 0.30984022661483185, 0.011851278351557122, 0.6901597733851683, 0.01185127835155712, 0.3593140496465053, 0.021591086637466894, 0.6406859503534936, 0.02159108663746693, 40.0, 90.0]
# isi:  40
# vdcc:  90
# Ca stats:
#  [2.25000000e-03 1.15969150e+01 2.21599991e-02 4.22500000e-02
#  1.63653760e+01 3.49153723e-02]
# Ca stats:
#  [2.25000000e-03 1.15969150e+01 2.21599991e-02 4.22500000e-02
#  1.63653760e+01 3.49153723e-02 4.00000000e+01 9.00000000e+01]
# R300ER2x RSI80V90.mdl
#
# Calculating Average of /dat/ca.dat
# RSI80V90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI60V90/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  60
# vdcc:  90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI80V90/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  80
# vdcc:  90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150ER2x/RSI80V90/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  80
# vdcc:  90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI80V90/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# resampling: 100
# isi:  80
# vdcc:  90
# seeds:  2000
# resampling: 200
# resampling: 300
# resampling: 400
# resampling: 100
# resampling: 500
# resampling: 200
# resampling: 600
# resampling: 300
# resampling: 700
# resampling: 400
# resampling: 800
# resampling: 500
# resampling: 900
# resampling: 600
# resampling: 1000
# Vesicle release stats:
#  [0.24406400000000006, 0.009504809519395953, 0.5795055000000001, 0.01062985041051849, 2.378186086894845, 0.1067252942999049, 0.39817992365914817, 0.01205323654152341, 0.601820076340852, 0.012053236541523413, 0.4896073772596917, 0.022650683766486844, 0.5103926227403083, 0.022650683766486858, 60.0, 90.0]
# isi:  60
# vdcc:  90
# Ca stats:
#  [2.25000000e-03 1.15969150e+01 2.21599991e-02 6.22000000e-02
#  1.57986490e+01 3.20470104e-02]
# Ca stats:
#  [2.25000000e-03 1.15969150e+01 2.21599991e-02 6.22000000e-02
#  1.57986490e+01 3.20470104e-02 6.00000000e+01 9.00000000e+01]
# R150control RSI100V90.mdl
#
# Calculating Average of /dat/ca.dat
# RSI100V90
# seeds:  2000
# resampling: 700
# resampling: 100
# resampling: 800
# resampling: 200
# resampling: 900
# resampling: 300
# resampling: 1000
# Vesicle release stats:
#  [0.20114499999999966, 0.008975075208598525, 0.4345070000000003, 0.010709969701170984, 2.164638657150446, 0.11368258535532308, 0.5500862306220655, 0.012056204570124802, 0.449913769377934, 0.012056204570124792, 0.6266252296413567, 0.022993063526957343, 0.37337477035864197, 0.022993063526957354, 80.0, 90.0]
# isi:  80
# vdcc:  90
# Ca stats:
#  [2.20000000e-03 1.16223710e+01 2.01596827e-02 8.22000000e-02
#  1.45242130e+01 2.71484484e-02]
# Ca stats:
#  [2.20000000e-03 1.16223710e+01 2.01596827e-02 8.22000000e-02
#  1.45242130e+01 2.71484484e-02 8.00000000e+01 9.00000000e+01]
# R150ER2x RSI100V90.mdl
#
# Calculating Average of /dat/ca.dat
# RSI100V90
# seeds:  2000
# resampling: 400
# resampling: 500
# resampling: 600
# resampling: 700
# resampling: 800
# resampling: 900
# resampling: 1000
# Vesicle release stats:
#  [0.2436025000000006, 0.009354931520326614, 0.5317805000000001, 0.01093089976854605, 2.1862658187265067, 0.09668283697319746, 0.45122635757062357, 0.012833041055149173, 0.5487736424293761, 0.012833041055149173, 0.5209781898857705, 0.022341927655618658, 0.4790218101142297, 0.02234192765561865, 80.0, 90.0]
# isi:  80
# vdcc:  90
# Ca stats:
#  [2.25000000e-03 1.15969150e+01 2.21599991e-02 8.22500000e-02
#  1.50895040e+01 3.02376633e-02]
# Ca stats:
#  [2.25000000e-03 1.15969150e+01 2.21599991e-02 8.22500000e-02
#  1.50895040e+01 3.02376633e-02 8.00000000e+01 9.00000000e+01]
# R300ER2x RSI100V90.mdl
#
# Calculating Average of /dat/ca.dat
# RSI100V90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI100V90/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  100
# vdcc:  90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150ER2x/RSI100V90/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  100
# vdcc:  90
# seeds:  2000
# resampling: 100
# resampling: 100
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI100V90/ca.dat
# resampling: 100
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  100
# vdcc:  90
# seeds:  2000
# resampling: 200
# resampling: 200
# resampling: 200
# resampling: 300
# resampling: 300
# resampling: 300
# resampling: 400
# resampling: 100
# resampling: 400
# resampling: 100
# resampling: 400
# resampling: 500
# resampling: 200
# resampling: 500
# resampling: 200
# resampling: 500
# resampling: 600
# resampling: 300
# resampling: 600
# resampling: 100
# resampling: 300
# resampling: 600
# resampling: 700
# resampling: 400
# resampling: 700
# resampling: 400
# resampling: 200
# resampling: 700
# resampling: 800
# resampling: 500
# resampling: 800
# resampling: 500
# resampling: 300
# resampling: 800
# resampling: 600
# resampling: 900
# resampling: 900
# resampling: 600
# resampling: 400
# resampling: 900
# resampling: 1000
# resampling: 700
# Vesicle release stats:
#  [0.17077400000000034, 0.008470591714868561, 0.38774199999999953, 0.010988445567959122, 2.2763766456734955, 0.1354537650399841, 0.6063354728668446, 0.012146513198247845, 0.39366452713315603, 0.012146513198247843, 0.641118688221885, 0.025608088275527102, 0.35888131177811544, 0.025608088275527123, 60.0, 90.0]
# isi:  60
# vdcc:  90
# Ca stats:
#  [2.20000000e-03 1.16938160e+01 1.86398489e-02 6.22000000e-02
#  1.44178270e+01 2.44770690e-02]
# Ca stats:
#  [2.20000000e-03 1.16938160e+01 1.86398489e-02 6.22000000e-02
#  1.44178270e+01 2.44770690e-02 6.00000000e+01 9.00000000e+01]
# resampling: 1000
# Vesicle release stats:
#  [0.17079350000000035, 0.008381175797583544, 0.4396794999999999, 0.011167386881003107, 2.5805777468872204, 0.14352322723617134, 0.5519895699569535, 0.01241754028624288, 0.4480104300430463, 0.01241754028624288, 0.6007196825952715, 0.026863175556764568, 0.3992803174047285, 0.026863175556764582, 40.0, 90.0]
# resampling: 700
# resampling: 500
# isi:  40
# vdcc:  90
# Ca stats:
#  [2.20000000e-03 1.16938160e+01 1.86398489e-02 4.22000000e-02
#  1.47788350e+01 2.58498470e-02]
# Ca stats:
#  [2.20000000e-03 1.16938160e+01 1.86398489e-02 4.22000000e-02
#  1.47788350e+01 2.58498470e-02 4.00000000e+01 9.00000000e+01]
# resampling: 100
# resampling: 1000
# Vesicle release stats:
#  [0.1707840000000001, 0.008404840510087046, 0.3674960000000006, 0.010882278437900782, 2.1571773039262214, 0.12672566032863752, 0.6280211014818254, 0.011941450935795819, 0.37197889851817445, 0.011941450935795812, 0.6542315266085384, 0.025568479877600025, 0.3457684733914614, 0.025568479877600046, 80.0, 90.0]
# isi:  80
# vdcc:  90
# Ca stats:
#  [2.20000000e-03 1.16938160e+01 1.86398489e-02 8.22000000e-02
#  1.39766290e+01 2.37346989e-02]
# Ca stats:
#  [2.20000000e-03 1.16938160e+01 1.86398489e-02 8.22000000e-02
#  1.39766290e+01 2.37346989e-02 8.00000000e+01 9.00000000e+01]
# resampling: 800
# resampling: 800
# resampling: 600
# resampling: 200
# resampling: 900
# resampling: 900
# resampling: 700
# resampling: 300
# resampling: 1000
# Vesicle release stats:
#  [0.1708375000000001, 0.008590217910507271, 0.31167300000000003, 0.010197772845087319, 1.8290590821376762, 0.1106056693454858, 0.6848102108506778, 0.011217298584159425, 0.31518978914932216, 0.011217298584159425, 0.7053613205266903, 0.024496192424776207, 0.29463867947331057, 0.02449619242477619, 100.0, 90.0]
# isi:  100
# vdcc:  90
# Ca stats:
#  [2.20000000e-03 1.16938160e+01 1.86398489e-02 1.02250000e-01
#  1.34755400e+01 2.30475214e-02]
# Ca stats:
#  [2.20000000e-03 1.16938160e+01 1.86398489e-02 1.02250000e-01
#  1.34755400e+01 2.30475214e-02 1.00000000e+02 9.00000000e+01]
# resampling: 100
# resampling: 800
# resampling: 1000
# Vesicle release stats:
#  [0.20041799999999974, 0.008957135479605076, 0.4206635000000009, 0.01062581845083002, 2.1032669396159713, 0.11074957337868874, 0.5715948639068311, 0.01214855273533948, 0.428405136093169, 0.012148552735339473, 0.6102235744355466, 0.02376944262034137, 0.3897764255644543, 0.023769442620341346, 100.0, 90.0]
# isi:  100
# vdcc:  90
# Ca stats:
#  [2.20000000e-03 1.16223710e+01 2.01596827e-02 1.02250000e-01
#  1.42159420e+01 2.63159483e-02]
# Ca stats:
#  [2.20000000e-03 1.16223710e+01 2.01596827e-02 1.02250000e-01
#  1.42159420e+01 2.63159483e-02 1.00000000e+02 9.00000000e+01]
# resampling: 400
# resampling: 200
# resampling: 900
# resampling: 500
# resampling: 1000
# Vesicle release stats:
#  [0.17459950000000007, 0.008405287011756342, 0.5615745000000003, 0.010829321296831113, 3.22409963040003, 0.17278621781874634, 0.42603283046994855, 0.012032945147796072, 0.5739671695300517, 0.012032945147796065, 0.49696791378283023, 0.026547282093524804, 0.5030320862171699, 0.026547282093524822, 20.0, 90.0]
# resampling: 300
# resampling: 600
# isi:  20
# vdcc:  90
# Ca stats:
#  [2.20000000e-03 1.16938160e+01 1.86478956e-02 2.22000000e-02
#  1.61323260e+01 2.85700206e-02]
# Ca stats:
#  [2.20000000e-03 1.16938160e+01 1.86478956e-02 2.22000000e-02
#  1.61323260e+01 2.85700206e-02 2.00000000e+01 9.00000000e+01]
# resampling: 400
# resampling: 700
# resampling: 500
# resampling: 800
# resampling: 600
# resampling: 900
# resampling: 700
# resampling: 1000
# Vesicle release stats:
#  [0.24439349999999993, 0.00926676360710686, 0.47609500000000016, 0.011400042763077678, 1.950932144334035, 0.08893525093724187, 0.5100897046175719, 0.013296868217281928, 0.4899102953824279, 0.013296868217281925, 0.566639594649728, 0.02294282244259262, 0.4333604053502723, 0.022942822442592634, 100.0, 90.0]
# isi:  100
# vdcc:  90
# Ca stats:
#  [2.25000000e-03 1.15969150e+01 2.21599991e-02 1.02250000e-01
#  1.46882490e+01 2.90342957e-02]
# Ca stats:
#  [2.25000000e-03 1.15969150e+01 2.21599991e-02 1.02250000e-01
#  1.46882490e+01 2.90342957e-02 1.00000000e+02 9.00000000e+01]
# resampling: 800
# resampling: 900
# resampling: 1000
# Vesicle release stats:
#  [0.2043979999999999, 0.009156942502822656, 0.6866754999999999, 0.009952986976280033, 3.3664631167539083, 0.1629471242722675, 0.2988802297761526, 0.011105670612657229, 0.701119770223849, 0.011105670612657227, 0.36954543559818276, 0.023453635983690102, 0.6304545644018172, 0.023453635983690106, 20.0, 90.0]
# isi:  20
# vdcc:  90
# Ca stats:
#  [2.20000000e-03 1.16223710e+01 2.01579523e-02 2.22500000e-02
#  1.69202770e+01 3.43282134e-02]
# Ca stats:
#  [2.20000000e-03 1.16223710e+01 2.01579523e-02 2.22500000e-02
#  1.69202770e+01 3.43282134e-02 2.00000000e+01 9.00000000e+01]
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
# Process ForkPoolWorker-325:
# Process ForkPoolWorker-321:
# Process ForkPoolWorker-319:
# Process ForkPoolWorker-322:
# Process ForkPoolWorker-326:
# Process ForkPoolWorker-323:
# Process ForkPoolWorker-320:
# Process ForkPoolWorker-324:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# AttributeError: Can't get attribute 'faverage' on <module '__main__'>
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'faverage' on <module '__main__'>
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# AttributeError: Can't get attribute 'faverage' on <module '__main__'>
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'faverage' on <module '__main__'>
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'faverage' on <module '__main__'>
# AttributeError: Can't get attribute 'faverage' on <module '__main__'>
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'faverage' on <module '__main__'>
# AttributeError: Can't get attribute 'faverage' on <module '__main__'>

# %%
def all_analysis(name,sim):
    print(sim,name)
    dataDirName = name.replace(".mdl","")
    dataType = "ppf/"+sim+"/"
    
    M=analysis(dataDirName,dataType)
    
    data_files=['ca.dat', 'ryr_mol.dat', 'serca_ca_flux.dat', 'vdcc_pq_ca_flux.dat', 'calbindin_mol.dat',\
            'serca_mol.dat', 'pmca&leak_ca_flux.dat', 'rrp.dat', 'ryr_ca_flux.dat']
    
    for data_file in data_files:
        M.avg_dat(inFile="/dat/"+data_file, outFile="/"+data_file)
    M.conc_calc(inFile="/ca.dat", outFile="/CaConc")

    isi = int(M.dataDirName.split("I")[1].split("V")[0])
    vdcc = int(M.dataDirName.split("V")[1])
    print('isi: ', isi, '\nvdcc: ', vdcc)

    M.relppf(isi, vdcc, resample=1000)

    M.caStat(showFig=True)

# %%
res_loc="/home/kabir/Project/tripartiteSynapse/results/ppf/"
result={}
for sim_type in sims[0:3]:
    result[sim_type]={}
    for name in fnames:
        loc=res_loc+sim_type+'/'+name.replace(".mdl","")+'/'+'result'
        if os.path.isfile(loc+'.dat'):
            os.rename(loc+'.dat',loc)
        with open(loc,'r') as f:
            l=f.readlines()
            result[sim_type][name]=[float(a) for a in l[2].replace('\n','').split('\t')]
#/home/kabir/Project/tripartiteSynapse/results/ppf/R150ER2x/RSI20V120

# %%
plt.figure(figsize=(10,6))
for sim_type in sims[0:3]:
    #print(result[sim_type])
    res=result[sim_type]
    xdata=[res[name][-2] for name in fnames]
    ydata=[res[name][4] for name in fnames]
    #print(ydata)
    plt.plot(xdata,ydata,label=sim_type)
plt.xlabel("ISI")
plt.ylabel("PPR")
plt.title("Effect of ER overload on PPF")
plt.legend()
#plt.savefig("/home/kabir/Project/tripartiteSynapse/plots/ppr.pdf")

# %%
def faverage(data_file):
    dataDirName="RSI20V90"
    dataType="ppf/R150control/"
    M=analysis(dataDirName,dataType)
    M.avg_dat(inFile="/dat/"+data_file, outFile="/"+data_file)
    
data_files=['az.dat', 'ryr_mol.dat', 'serca_ca_flux.dat', 'vdcc_pq_ca_flux.dat', 'calbindin_mol.dat',\
            'serca_mol.dat', 'pmca&leak_ca_flux.dat', 'rrp.dat', 'ryr_ca_flux.dat']

p=Pool(ncores-1)
p.starmap(faverage,product(data_files))
# Out:
# Calculating Average of
# Calculating Average of
# Calculating Average of
# Calculating Average of
# Calculating Average of
# Calculating Average of
# Calculating Average of /dat/vdcc_pq_ca_flux.dat
#  /dat/serca_ca_flux.dat
#  /dat/ryr_mol.dat
# RSI20V90
#  /dat/az.dat
# RSI20V90
#  /dat/serca_mol.dat
# RSI20V90
#  /dat/pmca&leak_ca_flux.dat
#  /dat/calbindin_mol.dat
# RSI20V90
# RSI20V90
# RSI20V90
# RSI20V90
# seeds:  2000
# seeds:  2000
# seeds:  2000
# seeds:  2000
# seeds:  2000
# seeds:  2000
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI20V90/vdcc_pq_ca_flux.dat
#
# Calculating Average of /dat/rrp.dat
# RSI20V90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI20V90/serca_ca_flux.dat
#
# Calculating Average of /dat/ryr_ca_flux.dat
# RSI20V90
# seeds:  2000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI20V90/pmca&leak_ca_flux.dat
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI20V90/serca_mol.dat
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI20V90/calbindin_mol.dat
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI20V90/ryr_mol.dat
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI20V90/rrp.dat
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI20V90/az.dat
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R150control/RSI20V90/ryr_ca_flux.dat
# [None, None, None, None, None, None, None, None, None]

# %%
for a in data_files:
    M.avg_dat(inFile="/dat/"+data_file, outFile="/"+data_file)
# Out:
# M.avg_dat(inFile='/dat/'+data_file, outFile='/'+data_file)
# M.avg_dat(inFile='/dat/'+data_file, outFile='/'+data_file)
# M.avg_dat(inFile='/dat/'+data_file, outFile='/'+data_file)
# M.avg_dat(inFile='/dat/'+data_file, outFile='/'+data_file)
# M.avg_dat(inFile='/dat/'+data_file, outFile='/'+data_file)
# M.avg_dat(inFile='/dat/'+data_file, outFile='/'+data_file)
# M.avg_dat(inFile='/dat/'+data_file, outFile='/'+data_file)
# M.avg_dat(inFile='/dat/'+data_file, outFile='/'+data_file)
# M.avg_dat(inFile='/dat/'+data_file, outFile='/'+data_file)

# %%
name="RSI60V90"
outfolder="R150ER2x"
data_loc="/data/kabir/output/ppf/"+outfolder+'/'+name
seed_folders=os.listdir(data_loc)
for s in seed_folders:
    file=data_loc+'/'+s+'/'+'dat/ca.dat'
    print(s,file_len(file))
# Out:
# s_01547 9002
# s_00027 9002
# s_00119 9002
# s_00499 9002
# s_01843 9002
# s_00387 9002
# s_00089 9002
# s_00342 9002
# s_01922 9002
# s_01393 9002
# s_00784 9002
# s_01093 9002
# s_01405 9002
# s_01973 9002
# s_00830 9002
# s_00056 9002
# s_00606 9002
# s_01255 9002
# s_00066 9002
# s_01114 9002
# s_00340 9002
# s_01363 9002
# s_00270 9002
# s_01443 9002
# s_00087 9002
# s_01070 9002
# s_00508 9002
# s_00095 9002
# s_00249 9002
# s_00217 9002
# s_01373 9002
# s_01277 9002
# s_01178 9002
# s_00012 9002
# s_00695 9002
# s_01647 9002
# s_00223 9002
# s_00931 9002
# s_01012 9002
# s_00793 9002
# s_00505 9002
# s_00669 9002
# s_00461 9002
# s_01418 9002
# s_00116 9002
# s_01251 9002
# s_00068 9002
# s_00584 9002
# s_00051 9002
# s_00082 9002
# s_00380 9002
# s_00825 9002
# s_01716 9002
# s_01407 9002
# s_00305 9002
# s_00715 9002
# s_01154 9002
# s_00679 9002
# s_00837 9002
# s_00246 9002
# s_00859 9002
# s_00378 9002
# s_01458 9002
# s_00968 9002
# s_00419 9002
# s_00561 9002
# s_01553 9002
# s_01250 9002
# s_00997 9002
# s_00638 9002
# s_01768 9002
# s_01753 9002
# s_00757 9002
# s_01958 9002
# s_01482 9002
# s_00120 9002
# s_00438 9002
# s_00369 9002
# s_00849 9002
# s_00037 9002
# s_00365 9002
# s_00221 9002
# s_01598 9002
# s_01170 9002
# s_01773 9002
# s_00839 9002
# s_00671 9002
# s_01327 9002
# s_00786 9002
# s_01577 9002
# s_01877 9002
# s_01875 9002
# s_01472 9002
# s_01283 9002
# s_01172 9002
# s_01441 9002
# s_01204 9002
# s_01527 9002
# s_00504 9002
# s_01499 9002
# s_01089 9002
# s_00376 9002
# s_01943 9002
# s_01066 9002
# s_01214 9002
# s_01268 9002
# s_01800 9002
# s_01746 9002
# s_00603 9002
# s_00033 9002
# s_01494 9002
# s_00628 9002
# s_01385 9002
# s_00598 9002
# s_00618 9002
# s_00808 9002
# s_01144 9002
# s_01286 9002
# s_01880 9002
# s_00014 9002
# s_00117 9002
# s_01303 9002
# s_01082 9002
# s_00689 9002
# s_01147 9002
# s_00151 9002
# s_01918 9002
# s_01974 9002
# s_01400 9002
# s_01892 9002
# s_00685 9002
# s_00753 9002
# s_01002 9002
# s_00986 9002
# s_01142 9002
# s_00528 9002
# s_00452 9002
# s_00500 9002
# s_00686 9002
# s_01453 9002
# s_00125 9002
# s_01470 9002
# s_01979 9002
# s_01301 9002
# s_01382 9002
# s_00610 9002
# s_01143 9002
# Process ForkPoolWorker-267:
# Process ForkPoolWorker-269:
# Process ForkPoolWorker-271:
# Process ForkPoolWorker-273:
# Process ForkPoolWorker-264:
# Process ForkPoolWorker-268:
# Process ForkPoolWorker-272:
# Process ForkPoolWorker-270:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-266:
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# s_01651 9002
# s_00189 9002
# s_00832 9002
# s_00058 9002
# s_00779 9002
# s_01386 9002
# s_01124 9002
# s_00398 9002
# s_01077 9002
# s_01604 9002
# s_01536 9002
# s_01613 9002
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# -------------------------------------------------------
# KeyboardInterrupt     Traceback (most recent call last)
# <ipython-input-255-b3f2e8f096ec> in <module>()
#       5 for s in seed_folders:
#       6     file=data_loc+'/'+s+'/'+'dat/ca.dat'
# ----> 7     print(s,file_len(file))
#       8
#
# <ipython-input-237-6bd5da584b1e> in file_len(fname)
#       2     i=-1
#       3     with open(fname) as f:
# ----> 4         for i, l in enumerate(f):
#       5             pass
#       6     return i + 1
#
# /usr/lib/python3.6/codecs.py in decode(self, input, final)
#     316         raise NotImplementedError
#     317
# --> 318     def decode(self, input, final=False):
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
#
# KeyboardInterrupt:
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-276:
# Process ForkPoolWorker-277:
# Process ForkPoolWorker-275:
# Process ForkPoolWorker-274:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
def file_len(fname):
    i=-1
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i + 1

# %%
"hi.bye".split('.')[0]
# Out:
# 'hi'

# %%
#combine glutamate release data for each seed
data_loc="/data/kabir/output/ppf/"+outfolder+'/'
#get seed folders
seed_folders=os.listdir(data_loc)

count=0
if "Average" in seed_folders:
    seed_folders.remove("Average")
for s in seed_folders:
    s=data_loc+s+"/dat/"
    file_names=os.listdir(s)
    output=[]
    for f_name in file_names:
        if 'vdcc.' in f_name:
            with open(s+f_name,'r') as f:
                output=output+f.readlines()
    with open(s+'rel.dat','w') as f:
        f.writelines(output)
    count+=len(output)

count/500
# Out:
# 0.67

# %%
# %run testLocal.py norm/RSI20V90
norm_ppf=ppf(resample=10)
# %run testLocal.py AD/RSI20V90
AD_ppf=ppf(resample=10)
print("normal PPR = ",norm_ppf[4])
print("AD PPR     = ",AD_ppf[4])
# Out:
# dataPath :  /data/kabir/output/ppf/norm/RSI20V90
# resultPath :  /home/kabir/Project/tripartiteSynapse/results/ppf/norm/RSI20V90
# isi:  20 vdcc:  90
# seeds:  500
# [0.0382, 0.008072174428244226, 0.34719999999999995, 0.02584879107424562, 9.611293613731359, 2.5516180832777358, 20.0, 90.0]
# dataPath :  /data/kabir/output/ppf/AD/RSI20V90
# resultPath :  /home/kabir/Project/tripartiteSynapse/results/ppf/AD/RSI20V90
# isi:  20 vdcc:  90
# seeds:  500
# [0.09159999999999999, 0.016044936896105262, 0.49840000000000007, 0.020293841430345325, 5.623162580693527, 1.070975085559397, 20.0, 90.0]
# normal PPR =  9.611293613731359
# AD PPR     =  5.623162580693527

# %%
# %run testLocal.py AD/RSI40V90
# Out:
# dataPath :  /data/kabir/output/ppf/AD/RSI40V90
# resultPath :  /home/kabir/Project/tripartiteSynapse/results/ppf/AD/RSI40V90

# %%
AD_ppf=ppf(resample=10)
# Out:
# isi:  40 vdcc:  90
# seeds:  500
# [0.0922, 0.014462364951832738, 0.403, 0.01782694589659148, 4.509857438817555, 0.8958789564708997, 40.0, 90.0]

# %%
# %run averaging1.ipynb

averager("/data/kabir/output/ppf/norm/RSI40V90","ca.dat",[2,3])

# %%
outfolder='norm/RSI20V40'
data_file="/data/kabir/output/ppf/norm/RSI20V40/Average/ca.dat"
data1=np.loadtxt(data_file)

outfolder='AD/RSI40V90/'
data_file="/data/kabir/output/ppf/AD/RSI40V90/Average/ca.dat"
data2=np.loadtxt(data_file)

# %%
#plt.plot(data1.T[0,:],data1.T[1,:],label='normal')#*1e15/N_avo/vol_er*1e6)
plt.plot(data2.T[0,:],data2.T[1,:],label='AD')#*1e15/N_avo/vol_er*1e6)
plt.legend()
# Out:
# -------------------------------------------------------
# NameError             Traceback (most recent call last)
# <ipython-input-3-d765f1bd29f5> in <module>()
#       1 #plt.plot(data1.T[0,:],data1.T[1,:],label='normal')#*1e15/N_avo/vol_er*1e6)
# ----> 2 plt.plot(data2.T[0,:],data2.T[1,:],label='AD')#*1e15/N_avo/vol_er*1e6)
#       3 plt.legend()
#
# NameError: name 'plt' is not defined

# %%
data1.T[:,0]
# Out:
# array([   0.,    0.,   57., 5872.])
