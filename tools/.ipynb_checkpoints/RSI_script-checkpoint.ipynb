# %%
import subprocess
from multiprocessing import Pool,cpu_count
import os
from itertools import product,repeat
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.interpolate import spline
from scipy.ndimage.filters import gaussian_filter1d
from scipy import stats
import fileinput as fi

# %run averaging.ipynb
# %run optimize_slope.ipynb

ncores=cpu_count()

# %%
area_er = 2*(3.9+0.1+0.1*0.1+3.9*0.1)
vol_er = (3.9*0.1*0.1)
vol_cyt = (4.0*0.5*0.5-vol_er)
vol_tot = vol_cyt + vol_er
N_avo=6.0221409e23

# %% [markdown]
# # Initial RSnostim equilibrium check

# %%
sims=["R150control","R150ER2x","R150ER3x","R300ER2x","R300ER3x"]
data_loc="/data/kabir/output/ppf/"
sim_type="RSnostim"

data_type=["ca.dat","pmca&leak_ca_flux.dat","serca_ca_flux.dat"]

plt.figure(figsize=(10,6))
for s in sims:
    data_folder=data_loc+s+'/'+sim_type
    data_file=data_folder+"/s_00001/dat/"+data_type[0]
    ca_dat=np.loadtxt(data_file)
    #print(ca_dat)
    ydata=ca_dat.T[3]*1e15/N_avo/vol_er*1e6
    #ydata=ca_dat.T[2]-ca_dat.T[1]
    xdata=ca_dat.T[0]
    plt.plot(xdata,ydata,label=s)
plt.legend()


plt.ylim((480,510))
# Out:
# (480, 510)

# %% [markdown]
# # Search and Replace in files

# %%
dataloc="/home/kabir/Project/tripartiteSynapse/mcell/R300ER2x/"
files=os.listdir(dataloc)
RSI_files=[]
for f in files:
    if "RSI" in f:
        RSI_files.append(f)
#RSI_files

# %%
for fn in RSI_files:
    with fi.FileInput(dataloc+fn,inplace=True, backup='.bak') as f:
        for line in f:
            print(line.replace('"ppf/"','"ppf/R300ER2x/"'), end='')

# %% [markdown]
# # kleak conversion to mcell

# %%
#from S Bandara et al 2013
J=0.07*250 #uM/s
J/=1e15/N_avo/vol_er*1e6
print("Ca Flux in ions/sec = ",J)

p=[2.1675959461586873, 6.214988757731395]
kleak=(J-p[1])/p[0]
print("Predicted kleak = ",kleak)
# Out:
# Ca Flux in ions/sec =  411.01111642500007
# Predicted kleak =  186.74888573427603

# %% [markdown]
# # creating run.sh file

# %%
def seed_num(fname):
    vdcc_num=int(fname.split('V')[1].replace('.mdl',''))
    if vdcc_num>=110 and vdcc_num<=160:
        return 1000
    elif vdcc_num>=90 and vdcc_num<=100:
        return 2000
    elif vdcc_num>=70 and vdcc_num<=80:
        return 3000
    elif vdcc_num>=40 and vdcc_num<=60:
        return 5000
    else:
        return 10

# %%
#VDCC range

sims=["R150control","R150ER2x","R300ER2x","R150ER3x","R300ER3x"]
sim_type=sims[3]
script_folder="/home/kabir/Project/tripartiteSynapse/mcell"+'/'+sim_type
print(script_folder)
isi=[20]
VDCC=list(range(60,170,20))
print('isi = '+str(isi),'\nvdcc = '+str(list(VDCC)))
fnames=[]
for (i,v) in product(isi,VDCC):
    fnames.append("RSI"+str(i)+"V"+str(v)+".mdl")
#fnames=["RSI20V90.mdl","RSI30V90.mdl","RSI40V90.mdl"]
print(fnames)
#seed_num=1000
# Out:
# /home/kabir/Project/tripartiteSynapse/mcell/R150ER3x
# isi = [20]
# vdcc = [60, 80, 100, 120, 140, 160]
# ['RSI20V60.mdl', 'RSI20V80.mdl', 'RSI20V100.mdl', 'RSI20V120.mdl', 'RSI20V140.mdl', 'RSI20V160.mdl']

# %%
#ISI range

sims=["R150control","R150ER2x","R300ER2x","R150ER3x","R300ER3x"]
sim_type=sims[2]
script_folder="/home/kabir/Project/tripartiteSynapse/mcell"+'/'+sim_type
print(script_folder)
isi=list(range(20,201,20))
VDCC=[90]
print('isi = '+str(isi),'\nvdcc = '+str(list(VDCC)))
fnames=[]
for (i,v) in product(isi,VDCC):
    fnames.append("RSI"+str(i)+"V"+str(v)+".mdl")
#fnames=["RSI20V90.mdl","RSI30V90.mdl","RSI40V90.mdl"]
print(fnames)
#seed_num=1000
# Out:
# /home/kabir/Project/tripartiteSynapse/mcell/R300ER2x
# isi = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200]
# vdcc = [90]
# ['RSI20V90.mdl', 'RSI40V90.mdl', 'RSI60V90.mdl', 'RSI80V90.mdl', 'RSI100V90.mdl', 'RSI120V90.mdl', 'RSI140V90.mdl', 'RSI160V90.mdl', 'RSI180V90.mdl', 'RSI200V90.mdl']

# %%
a="""for name in fnames:
    input_loc=script_folder+'/'+name.replace('V90','V80')
    output_loc=script_folder+'/'+name
    with open(input_loc,'r') as infile:
        lines=infile.readlines()
    
    lines=[line.replace("VDCC_number_presynaptic = 80","VDCC_number_presynaptic = 90") for line in lines]
        
    with open(output_loc,'w') as outfile:
        outfile.writelines(lines)
#"""

# %%
#write run.sh
with open(script_folder+'/run.sh','w') as f:
    for name in fnames:
            loc=script_folder+'/'+name
            f.write("sed --i 's/^#PBS -J.*/#PBS -J 1-"+str(seed_num(name))+"/' pbs.py\n")
            f.write("qsub -N "+name.replace(".mdl",sim_type).replace("RSI",'I')+" -v I='"+loc.replace('/kabir/Project/','/subhadra/kabir/')+"' pbs.py\n")
            f.write("\n")

# %%
#sync script files to cluster
p=subprocess.call(["rsync","-arhP",script_folder,"subhadra@192.168.1.244:/home/subhadra/kabir/tripartiteSynapse/mcell/"])

# %%
outfolder='AD/RSI40V90'

# %%
outfolder='AD'#RSI40V90'

# %%
#sync data back to this system
p=subprocess.call(["rsync","-arhP","subhadra@192.168.1.244:/storage/subhadra/kabir/output/ppf/"+outfolder,"/data/kabir/output/ppf/"])

# %%
outfolder='R150control'#RSI40V90'

# %%
#sync data back to this system
p=subprocess.call(["rsync","-arhP","subhadra@192.168.1.244:/storage/subhadra/kabir/output/ppf/"+outfolder,"/data/kabir/output/ppf/"])

# %%
# %run analysis.ipynb
p=Pool(ncores)
#print(fnames)
p.starmap(all_analysis,product(fnames))
#all_analysis(fnames[-1])
# Out:
# RSI20V60.mdl
# RSI20V120.mdl
# RSI20V160.mdl
# RSI20V140.mdl
# RSI20V100.mdl
#
# Calculating Average ofRSI20V80.mdl
#
# Calculating Average of
# Calculating Average of
# Calculating Average of
# Calculating Average of /dat/ca.dat
#
# Calculating Average of /dat/ca.dat
#  /dat/ca.dat
#  /dat/ca.dat
#  /dat/ca.dat
#  /dat/ca.dat
# seeds:  1000
# seeds:  1000
# seeds:  2000
# seeds:  3000
# seeds:  1000
# seeds:  5000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI20V120/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  20
# vdcc:  120
# seeds:  1000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI20V140/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  20
# vdcc:  140
# seeds:  1000
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI20V160/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  20
# vdcc:  160
# seeds:  1000
# resampling: 100
# resampling: 200
# resampling: 100
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI20V100/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  20
# vdcc:  100
# seeds:  2000
# resampling: 300
# resampling: 100
# resampling: 200
# resampling: 400
# resampling: 200
# resampling: 300
# resampling: 500
# resampling: 400
# resampling: 300
# resampling: 600
# resampling: 400
# resampling: 500
# resampling: 700
# resampling: 500
# resampling: 600
# resampling: 800
# resampling: 700
# resampling: 600
# resampling: 100
# resampling: 800
# resampling: 900
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI20V80/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  20
# vdcc:  80
# seeds:  3000
# resampling: 900
# resampling: 700
# resampling: 1000
# Vesicle release stats:
#  [0.47289900000000074, 0.01532653904180587, 0.8258209999999995, 0.012459091419521737, 1.7481942955262832, 0.06430109784712806, 0.1316975790583838, 0.01528616676827191, 0.8683024209416164, 0.015286166768271894, 0.22149649204561847, 0.019088882027792853, 0.7785035079543827, 0.019088882027792867, 20.0, 120.0]
# isi:  20
# vdcc:  120
# Ca stats:
#  [2.20000000e-03 1.74410490e+01 2.47453564e-02 2.22500000e-02
#  2.37069510e+01 3.64367862e-02]
# Ca stats:
#  [2.20000000e-03 1.74410490e+01 2.47453564e-02 2.22500000e-02
#  2.37069510e+01 3.64367862e-02 2.00000000e+01 1.20000000e+02]
# resampling: 200
# resampling: 1000
# Vesicle release stats:
#  [0.679852, 0.014446594616033183, 0.932038, 0.00774548616937631, 1.3715803091205543, 0.032125695999704315, 0.03710366012040475, 0.010846341029723231, 0.9628963398795949, 0.010846341029723237, 0.0824834720166199, 0.010512768434268512, 0.9175165279833803, 0.010512768434268486, 20.0, 140.0]
# isi:  20
# vdcc:  140
# Ca stats:
#  [2.25000000e-03 2.18516580e+01 2.98404495e-02 2.22500000e-02
#  2.90207520e+01 4.49328428e-02]
# Ca stats:
#  [2.25000000e-03 2.18516580e+01 2.98404495e-02 2.22500000e-02
#  2.90207520e+01 4.49328428e-02 2.00000000e+01 1.40000000e+02]resampling: 800
#
# resampling: 300
# resampling: 900
# resampling: 1000
# Vesicle release stats:
#  [0.9056629999999988, 0.009455973297339638, 0.9738610000000011, 0.005035243688243909, 1.0754186781884256, 0.012506504527281685, 0.0, 0.0, 1.0, 0.0, 0.028865252907658998, 0.0055697942514322096, 0.9711347470923424, 0.0055697942514322096, 20.0, 160.0]
# isi:  20
# vdcc:  160
# Ca stats:
#  [2.20000000e-03 2.81982560e+01 3.67319438e-02 2.22000000e-02
#  3.69515680e+01 5.61589337e-02]
# Ca stats:
#  [2.20000000e-03 2.81982560e+01 3.67319438e-02 2.22000000e-02
#  3.69515680e+01 5.61589337e-02 2.00000000e+01 1.60000000e+02]
# resampling: 400
# resampling: 500
# resampling: 600
# Writing average to: /home/kabir/Project/tripartiteSynapse/results/ppf/R300ER2x/RSI20V60/ca.dat
# Calculating Calcium Concentration...
# Writing Ca Conc. to file:/CaConc
# isi:  20
# vdcc:  60
# seeds:  5000
# resampling: 700
# resampling: 100
# resampling: 800
# resampling: 200
# resampling: 900
# resampling: 300
# resampling: 1000
# Vesicle release stats:
#  [0.21339950000000005, 0.009615360094661041, 0.5661440000000003, 0.010760565226789889, 2.658456617610585, 0.1317956607455589, 0.4238060519374344, 0.012376560090271577, 0.5761939480625656, 0.012376560090271577, 0.47081894470556734, 0.023332741042656074, 0.5291810552944325, 0.02333274104265606, 20.0, 100.0]
# isi:  20
# vdcc:  100
# Ca stats:
#  [2.20000000e-03 1.24682170e+01 1.92199630e-02 2.22000000e-02
#  1.70760230e+01 2.80970405e-02]
# Ca stats:
#  [2.20000000e-03 1.24682170e+01 1.92199630e-02 2.22000000e-02
#  1.70760230e+01 2.80970405e-02 2.00000000e+01 1.00000000e+02]
# resampling: 400
# resampling: 500
# resampling: 600
# resampling: 100
# resampling: 700
# resampling: 800
# resampling: 200
# resampling: 900
# resampling: 1000
# Vesicle release stats:
#  [0.06646533333333342, 0.004452030547963482, 0.2604949999999997, 0.007759050450209032, 3.9373898965705663, 0.2961501677873632, 0.7348315574380931, 0.008114338170533378, 0.2651684425619077, 0.008114338170533381, 0.8051905626688186, 0.02679994776375418, 0.1948094373311827, 0.026799947763754186, 20.0, 80.0]
# resampling: 300
# isi:  20
# vdcc:  80
# Ca stats:
#  [2.20000000e-03 8.52355100e+00 1.46416938e-02 2.22000000e-02
#  1.21763190e+01 2.12270679e-02]
# Ca stats:
#  [2.20000000e-03 8.52355100e+00 1.46416938e-02 2.22000000e-02
#  1.21763190e+01 2.12270679e-02 2.00000000e+01 8.00000000e+01]
# resampling: 400
# resampling: 500
# resampling: 600
# resampling: 700
# resampling: 800
# resampling: 900
# resampling: 1000
# Vesicle release stats:
#  [0.010412799999999984, 0.0013777939468585286, 0.06327560000000004, 0.003387347729418989, 6.186897066671382, 0.9130743273592642, 0.936467140151383, 0.00341114032632416, 0.06353285984861685, 0.003411140326324156, 0.961266520618208, 0.026505951418112954, 0.03873347938179495, 0.026505951418113016, 20.0, 60.0]
# isi:  20
# vdcc:  60
# Ca stats:
#  [2.20000000e-03 4.87384800e+00 1.02471838e-02 2.22500000e-02
#  7.36967100e+00 1.49610570e-02]
# Ca stats:
#  [2.20000000e-03 4.87384800e+00 1.02471838e-02 2.22500000e-02
#  7.36967100e+00 1.49610570e-02 2.00000000e+01 6.00000000e+01]
# [None, None, None, None, None, None]

# %%
def all_analysis(name):
    print(name)
    dataDirName = name.replace(".mdl","")
    dataType = "ppf/R300ER2x/"
    
    M=analysis(dataDirName,dataType)

    M.avg_dat(inFile="/dat/ca.dat", outFile="/ca.dat")
    M.conc_calc(inFile="/ca.dat", outFile="/CaConc")

    isi = int(M.dataDirName.split("I")[1].split("V")[0])
    vdcc = int(M.dataDirName.split("V")[1])
    print('isi: ', isi, '\nvdcc: ', vdcc)

    M.relppf(isi, vdcc, resample=1000)

    M.caStat(showFig=True)

# %%
res_loc="/home/kabir/Project/tripartiteSynapse/results/ppf/"
result={}
for sim_type in sims[0:3]:
    result[sim_type]={}
    for name in fnames:
        loc=res_loc+sim_type+'/'+name.replace(".mdl","")+'/'+'result'
        if os.path.isfile(loc+'.dat'):
            os.rename(loc+'.dat',loc)
        with open(loc,'r') as f:
            l=f.readlines()
            result[sim_type][name]=[float(a) for a in l[2].replace('\n','').split('\t')]
#/home/kabir/Project/tripartiteSynapse/results/ppf/R150ER2x/RSI20V120

# %%
plt.figure(figsize=(10,6))
for sim_type in sims[0:3]:
    #print(result[sim_type])
    res=result[sim_type]
    xdata=[res[name][0] for name in fnames]
    ydata=[res[name][4] for name in fnames]
    #print(ydata)
    plt.plot(xdata,ydata,label=sim_type)
plt.xlabel("Basal Probability P1")
plt.ylabel("PPR")
plt.title("Effect of ER overload on PPF")
plt.legend()
#plt.savefig("/home/kabir/Project/tripartiteSynapse/plots/ppr.pdf")

# %%
#combine glutamate release data for each seed
data_loc="/data/kabir/output/ppf/"+outfolder+'/'
#get seed folders
seed_folders=os.listdir(data_loc)

count=0
if "Average" in seed_folders:
    seed_folders.remove("Average")
for s in seed_folders:
    s=data_loc+s+"/dat/"
    file_names=os.listdir(s)
    output=[]
    for f_name in file_names:
        if 'vdcc.' in f_name:
            with open(s+f_name,'r') as f:
                output=output+f.readlines()
    with open(s+'rel.dat','w') as f:
        f.writelines(output)
    count+=len(output)

count/500
# Out:
# 0.67

# %%
# %run testLocal.py norm/RSI20V90
norm_ppf=ppf(resample=10)
# %run testLocal.py AD/RSI20V90
AD_ppf=ppf(resample=10)
print("normal PPR = ",norm_ppf[4])
print("AD PPR     = ",AD_ppf[4])
# Out:
# dataPath :  /data/kabir/output/ppf/norm/RSI20V90
# resultPath :  /home/kabir/Project/tripartiteSynapse/results/ppf/norm/RSI20V90
# isi:  20 vdcc:  90
# seeds:  500
# [0.0382, 0.008072174428244226, 0.34719999999999995, 0.02584879107424562, 9.611293613731359, 2.5516180832777358, 20.0, 90.0]
# dataPath :  /data/kabir/output/ppf/AD/RSI20V90
# resultPath :  /home/kabir/Project/tripartiteSynapse/results/ppf/AD/RSI20V90
# isi:  20 vdcc:  90
# seeds:  500
# [0.09159999999999999, 0.016044936896105262, 0.49840000000000007, 0.020293841430345325, 5.623162580693527, 1.070975085559397, 20.0, 90.0]
# normal PPR =  9.611293613731359
# AD PPR     =  5.623162580693527

# %%
# %run testLocal.py AD/RSI40V90
# Out:
# dataPath :  /data/kabir/output/ppf/AD/RSI40V90
# resultPath :  /home/kabir/Project/tripartiteSynapse/results/ppf/AD/RSI40V90

# %%
AD_ppf=ppf(resample=10)
# Out:
# isi:  40 vdcc:  90
# seeds:  500
# [0.0922, 0.014462364951832738, 0.403, 0.01782694589659148, 4.509857438817555, 0.8958789564708997, 40.0, 90.0]

# %%
# %run averaging1.ipynb

averager("/data/kabir/output/ppf/norm/RSI40V90","ca.dat",[2,3])

# %%
outfolder='norm/RSI20V40'
data_file="/data/kabir/output/ppf/norm/RSI20V40/Average/ca.dat"
data1=np.loadtxt(data_file)

outfolder='AD/RSI40V90/'
data_file="/data/kabir/output/ppf/AD/RSI40V90/Average/ca.dat"
data2=np.loadtxt(data_file)

# %%
#plt.plot(data1.T[0,:],data1.T[1,:],label='normal')#*1e15/N_avo/vol_er*1e6)
plt.plot(data2.T[0,:],data2.T[1,:],label='AD')#*1e15/N_avo/vol_er*1e6)
plt.legend()
# Out:
# -------------------------------------------------------
# NameError             Traceback (most recent call last)
# <ipython-input-3-d765f1bd29f5> in <module>()
#       1 #plt.plot(data1.T[0,:],data1.T[1,:],label='normal')#*1e15/N_avo/vol_er*1e6)
# ----> 2 plt.plot(data2.T[0,:],data2.T[1,:],label='AD')#*1e15/N_avo/vol_er*1e6)
#       3 plt.legend()
#
# NameError: name 'plt' is not defined

# %%
data1.T[:,0]
# Out:
# array([   0.,    0.,   57., 5872.])
